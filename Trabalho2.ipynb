# %% [markdown]
# # Trabalho 2 de Finanças Quantitativas - UFMG
#
# ## Prof. Cristiano Arbex
# ## Eduardo Santiago Ramos

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

import csv
import urllib
import io
import requests
import pickle

import datetime
import scipy.stats as scs
import statsmodels.stats.stattools as smstools

import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
py.init_notebook_mode(connected=True)

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # 0. Manipulacao de dados
#
# Fonte: Arquivo *dados.pdf*

# %% [markdown]
# ## 0.1. Funcoes auxiliares

# %%
def plotscatter(df, columns=None, name='Stock name', title='Stock price', yaxis='Preco'):
    '''Imprime series temporais'''
    if columns is None: columns=df.columns
        
    # 1) Traces
    df_data = list(go.Scatter(x=df.index, y=df[col], name=col) for col in columns)

    # 2) Layout
    df_layout = go.Layout(title=title, legend={'orientation':'h'}, yaxis={'title':yaxis})

    # 3) Figure
    df_fig = go.Figure(data=df_data, layout=df_layout)
    py.iplot(df_fig)

# %%
def dados_do_trabalho(url, file_name):
    '''Le/baixa dados do trabalho 1 de Financas Quantitativas'''
    save_path = '{}.pkl'.format(file_name)
    try:
        with open(save_path, 'rb') as f:
            df = pickle.load(f)
            print(f'Dados lidos de {save_path}')
    except (OSError, IOError) as e:
        print('Baixando dados de {}'.format(url))
        s = requests.get(url).content
        df = pd.read_csv(io.StringIO(s.decode('utf-8')))
        df.to_pickle(save_path)
        print(f'Salvo em {save_path}')
        
    return df

# %% [markdown]
# ## 0.2. Download dos dados

# %%
df_raw_daily = dados_do_trabalho("http://www.dcc.ufmg.br/~arbex/portfolios/IBOV.csv", 'ibov_diario')
# Out:
# Dados lidos de ibov_diario.pkl

# %%
df_raw_daily
# Out:
#           Date      IBOV  BOVA11  ABEV3  BVMF3  BBDC3  BBAS3  SANB11  BBSE3  \
# 0     20070102  45382.61    0.00   2.68   0.00   9.82  11.05    0.00   0.00
# 1     20070103  44445.29    0.00   2.66   0.00   9.71  10.85    0.00   0.00
# 2     20070104  44019.77    0.00   2.66   0.00   9.75  11.25    0.00   0.00
# 3     20070105  42245.16    0.00   2.61   0.00   9.35  10.76    0.00   0.00
# 4     20070108  42829.93    0.00   2.66   0.00   9.65  11.01    0.00   0.00
# 5     20070109  42006.78    0.00   2.64   0.00   9.40  10.89    0.00   0.00
# 6     20070110  42335.67    0.00   2.63   0.00   9.36  10.86    0.00   0.00
# 7     20070111  42670.32    0.00   2.66   0.00   9.48  11.02    0.00   0.00
# 8     20070112  43094.97    0.00   2.72   0.00   9.66  11.06    0.00   0.00
# 9     20070115  42919.17    0.00   2.74   0.00   9.71  11.23    0.00   0.00
# 10    20070116  42624.22    0.00   2.74   0.00   9.79  11.16    0.00   0.00
# 11    20070117  42735.48    0.00   2.76   0.00   9.80  11.30    0.00   0.00
# 12    20070118  42477.92    0.00   2.74   0.00   9.71  11.47    0.00   0.00
# 13    20070119  43427.64    0.00   2.72   0.00   9.93  11.62    0.00   0.00
# 14    20070122  43553.30    0.00   2.77   0.00   9.97  11.60    0.00   0.00
# 15    20070123  44177.20    0.00   2.77   0.00   9.99  11.43    0.00   0.00
#
#       VALE3  VVAR11
# 0      0.00    0.00
# 1      0.00    0.00
# 2      0.00    0.00
# 3      0.00    0.00
# 4      0.00    0.00
# 5      0.00    0.00
# 6      0.00    0.00
# 7      0.00    0.00
# 8      0.00    4.11
# 9      0.00    5.29
# 10     0.00    7.35
# 11     0.00    7.17
# 12     0.00    7.00
# 13     0.00    6.83
# 14     0.00    6.66
# 15     0.00    6.49
# 16     0.00    6.32
# 17     0.00    6.15
# 18     0.00    5.97
# 19     0.00    5.80
# 20     0.00    5.63
# 21     0.00    5.46
# 22     0.00    5.29
# 23     0.00    5.29
# 24     0.00    5.29
# 25     0.00    5.29
# 26     0.00    5.29
# 27     0.00    5.29
# 28     0.00    5.29
# 29     0.00    5.29
# ...     ...     ...
# 2729  23.31   25.96
# 2730  23.15   25.81
# 2731  22.52   25.45
# 2732  23.48   25.80
# 2733  24.22   25.51
# 2734  24.19   24.72
# 2735  26.33   24.81
# 2736  27.85   24.92
# 2737  27.80   24.12
# 2738  27.60   23.91
# 2739  27.12   23.62
# 2740  27.88   23.42
# 2741  26.72   22.67
# 2742  25.63   22.42
# 2743  25.40   23.10
# 2744  24.84   22.82
# 2745  25.25   22.15
# 2746  24.36   21.84
# 2747  25.89   22.82
# 2748  26.47   23.33
# 2749  27.00   22.79
# 2750  26.68   22.89
# 2751  25.80   22.87
# 2752  26.36   22.76
# 2753  27.70   22.91
# 2754  28.00   23.77
# 2755  28.34   24.07
# 2756  27.66   23.72
# 2757  27.39   23.33
# 2758  28.18   23.20
#
# [2759 rows x 65 columns]

# %% [markdown]
# ## 0.3. Transformacao de indices para datas

# %%
df_diario = df_raw_daily.copy() # faz copia do original

# %%
# Funcao que transforma data em formato inteiro em tipo datetime
dayint2date = lambda date_int: pd.to_datetime(date_int, format='%Y%m%d')

# Aplica na coluna 'Date'
df_diario['Date'] = df_diario['Date'].apply(dayint2date)

# Seta os indices para ser a coluna 'Date'
df_diario = df_diario.set_index('Date')

# %%
# Primeiras/ultimas linhas de cada data frame
df_diario
# Out:
#                 IBOV  BOVA11  ABEV3  BVMF3  BBDC3  BBAS3  SANB11  BBSE3  \
# Date
# 2007-01-02  45382.61    0.00   2.68   0.00   9.82  11.05    0.00   0.00
# 2007-01-03  44445.29    0.00   2.66   0.00   9.71  10.85    0.00   0.00
# 2007-01-04  44019.77    0.00   2.66   0.00   9.75  11.25    0.00   0.00
# 2007-01-05  42245.16    0.00   2.61   0.00   9.35  10.76    0.00   0.00
# 2007-01-08  42829.93    0.00   2.66   0.00   9.65  11.01    0.00   0.00
# 2007-01-09  42006.78    0.00   2.64   0.00   9.40  10.89    0.00   0.00
# 2007-01-10  42335.67    0.00   2.63   0.00   9.36  10.86    0.00   0.00
# 2007-01-11  42670.32    0.00   2.66   0.00   9.48  11.02    0.00   0.00
# 2007-01-12  43094.97    0.00   2.72   0.00   9.66  11.06    0.00   0.00
# 2007-01-15  42919.17    0.00   2.74   0.00   9.71  11.23    0.00   0.00
# 2018-02-14  11.97  44.01  25.89   22.82
# 2018-02-15  12.13  45.43  26.47   23.33
# 2018-02-16  12.12  45.51  27.00   22.79
# 2018-02-19  12.14  45.93  26.68   22.89
# 2018-02-20  12.10  45.00  25.80   22.87
# 2018-02-21  12.15  44.30  26.36   22.76
# 2018-02-22  12.01  45.16  27.70   22.91
# 2018-02-23  12.20  45.56  28.00   23.77
# 2018-02-26  12.75  46.87  28.34   24.07
# 2018-02-27  12.65  46.80  27.66   23.72
# 2018-02-28  12.32  44.54  27.39   23.33
# 2018-03-01  11.80  43.95  28.18   23.20
#
# [2759 rows x 64 columns]

# %% [markdown]
# ## 0.4. Presenca de zeros

# %%
df_diario = df_diario.replace(0, np.nan) # troca 0 por NaN

# %% [markdown]
# # <span style='color:darkmagenta'>Questao 1.</span>
#
# Neste exercício vamos selecionar portfolios baseados em Markowitz e otimização de CVaR. A
# ideia é escolher portfolios compostos pelos ativos do índice iBOV no primeiro dia útil de Fevereiro 2018 e
# ver como se comportariam no mês. Vamos utilizar os dois anos anteriores como dados de entrada, entre
# os inícios de Fevereiro de 2016 e Fevereiro de 2018. Se quiserem, podem utilizar o seguinte código em R
# para preparar os dados:

# %%
prices = df_diario.copy()

# Inicio e fim das series in-sample e out-of-sample
inSampleInicio = prices.index[prices.index>='2016-02'][0]
inSampleFim = prices.index[prices.index<'2018-02'][-1]
outOfSampleInicio = prices.index[prices.index>='2018-02'][0]
outOfSampleFim = prices.index[-1]

# Eliminando empresas que possuem precos invalidos
iISI = prices.index.get_loc(inSampleInicio)
iISF = prices.index.get_loc(inSampleFim)
prices = prices.dropna(how='any', axis=1, subset=prices.index[iISI:iISF])

# Dados in-sample apenas das acoes do iBov
pricesIS = prices[inSampleInicio:inSampleFim].drop(columns=['IBOV','BOVA11'])
returnsIS = (pricesIS.diff() / pricesIS.shift(axis=0, periods=1)).iloc[1:]

# Dados out-of-sample apenas das acoes do iBov
pricesOS = prices[outOfSampleInicio:outOfSampleFim].drop(columns=['IBOV','BOVA11'])

# Outros dados out-of-sample
indexPriceOS = prices.loc[outOfSampleInicio:outOfSampleFim, 'IBOV']

# Numero de ativos e de cenarios
S, N = returnsIS.shape

pricesIS
# returnsIS
# pricesOS
# indexPriceOS
# Out:
#             ABEV3  BVMF3  BBDC3  BBAS3  SANB11  BBSE3  BRML3  BBDC4  BRAP4  \
# Date
# 2016-02-01  17.33   9.94  15.10  13.02   11.95  20.21   7.99  14.10   3.17
# 2016-02-02  16.94   9.69  14.48  12.05   11.25  19.35   7.72  13.54   2.90
# 2016-02-03  17.05   9.86  15.40  12.21   11.47  19.84   7.82  14.19   3.04
# 2016-02-04  17.29   9.96  16.43  12.69   12.05  20.16   8.12  14.96   3.47
# 2016-02-05  17.09   9.79  15.92  12.59   12.21  20.64   8.22  14.81   3.47
# 2016-02-10  16.90   9.81  16.02  12.59   12.26  20.64   8.18  14.98   3.36
# 2016-02-11  16.81   9.69  15.75  12.01   11.92  19.87   8.18  14.59   3.19
# 2018-01-08  42.74  23.90   24.61
# 2018-01-09  42.59  23.52   25.01
# 2018-01-10  41.99  23.21   24.81
# 2018-01-11  42.81  23.25   25.29
# 2018-01-12  43.06  23.39   25.48
# 2018-01-15  42.98  23.75   25.65
# 2018-01-16  41.82  23.31   25.96
# 2018-01-17  42.67  23.15   25.81
# 2018-01-18  42.38  22.52   25.45
# 2018-01-19  42.40  23.48   25.80
# 2018-01-22  42.17  24.22   25.51
# 2018-01-23  40.41  24.19   24.72
# 2018-01-24  41.31  26.33   24.81
# 2018-01-26  40.96  27.85   24.92
# 2018-01-29  41.42  27.80   24.12
# 2018-01-30  41.00  27.60   23.91
# 2018-01-31  40.98  27.12   23.62
#
# [497 rows x 60 columns]

# %% [markdown]
# ### a. Utilizando como entrada os dados in-sample, plote um gráfico com a fronteira eficiente utilizando o modelo de Markowitz. Varie o retorno de 0 a 0.008 com intervalos 0.0001 e permita shorting. Uma dica é utilizar o pacote `quadprog` para resolver o modelo, para ajuda verifique o Exemplo 7.12 das Lecture notes.

# %% [markdown]
# ### [Resp]
#
# A formulação de programação quadrática para o problema é a seguinte:
#
# \begin{align}
#     &\underset{w}{\text{minimize}} &&\frac{1}{2}\sum_{i=1}^{N}\sum_{j=1}^{N}w_iw_j\sigma_{ij} &&\equiv \quad &&\frac{1}{2} \mathbf{w^T}\mathbf{\Sigma}\mathbf{w} \\
#     &\text{sujeito a} &&\sum_{i=1}^{N}w_i\mu_i \geq \overline{\mu} &&\equiv &&\mathbf{\mu^T}\mathbf{w} \geq \overline{\mu}\\
#     & &&\sum_{i=1}^{N}w_i = 1 &&\equiv &&\mathbf{1^T}\mathbf{w} = 1 \\
# \end{align}
#
# - A variável de decisão é $\mathbf{w}$.
# - Os parâmetros fixos do modelo - retornos médios $\mu_i$ e covariâncias $\sigma_{ij}$ - são obtidos do conjunto `returnsIS`.
# - Já os parâmetros variável - retorno mínimo $\overline{\mu}$ - é definido no intervalo entre $0$ e $0.008$, com passos de $0.0001$, a fim de obter um gráficom com a fronteira eficiente.
# - A fim de permitir *shorting*, $\mathbf{w}$ é irrestrita.

# %%
import quadprog

# Matriz de retornos para extrair parametros
RetMat = returnsIS.values.T

# Obtendo parametros fixos do modelo
Sigma = np.cov(RetMat)       # matriz de covariancia
mu = np.mean(RetMat, axis=1) # retornos medios por ativo

# Definindo retornos minimos
ret = np.arange(0,0.0081,0.0001)
risk = np.empty(ret.shape)
for i, mu_min in enumerate(ret):
    print('Solucionando para retorno minimo de %.4f' % mu_min)
    
    # Matrizes de otimizacao
    G = Sigma                           # matriz de custo quadratico
    a = np.zeros(N)                     # vetor de custo (nao existe)
    C = np.vstack([np.ones(N), mu]).T   # matriz de m restricoes
    b = np.array([1, mu_min])           # termos a direita
    meq = 1                             # primeira restricao e' de igualdade

    # Verificacao de dimensoes
    n = N
    m = 2
    assert G.shape==(n,n) and a.shape==(n,) and C.shape==(n,m) and b.shape==(m,)
    
    # Soluciona problema quadratico
    quad_sol = quadprog.solve_qp(G, a, C, b, meq)
    (w_opt,f_opt) = quad_sol[0:2]
    risk[i] = f_opt
    
    # Validacao e impressao de dados:
    print('Porcentagem do orcamento investido: %.2f %%' % (np.matmul(np.ones(N),w_opt)*100))
    print('Retorno do portfolio: %.5f ' % np.matmul(mu,w_opt))
    print('Variancia do portfolio: %.5f \n' % f_opt)
# Out:
# Solucionando para retorno minimo de 0.0000
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0001
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0002
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0003
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0004
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0005
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0006
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00066
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0007
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00070
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0008
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00080
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0009
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00090
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0010
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00100
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0011
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00110
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0012
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00120
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0013
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00130
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0014
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00140
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0015
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00150
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0016
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00160
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0017
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00170
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0018
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00180
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0019
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00190
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0020
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00200
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0021
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00210
# Variancia do portfolio: 0.00002
#
# Solucionando para retorno minimo de 0.0022
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00220
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0023
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00230
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0024
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00240
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0025
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00250
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0026
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00260
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0027
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00270
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0028
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00280
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0029
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00290
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0030
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00300
# Variancia do portfolio: 0.00003
#
# Solucionando para retorno minimo de 0.0031
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00310
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0032
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00320
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0033
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00330
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0034
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00340
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0035
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00350
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0036
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00360
# Variancia do portfolio: 0.00004
#
# Solucionando para retorno minimo de 0.0037
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00370
# Variancia do portfolio: 0.00005
#
# Solucionando para retorno minimo de 0.0038
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00380
# Variancia do portfolio: 0.00005
#
# Solucionando para retorno minimo de 0.0039
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00390
# Variancia do portfolio: 0.00005
#
# Solucionando para retorno minimo de 0.0040
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00400
# Variancia do portfolio: 0.00005
#
# Solucionando para retorno minimo de 0.0041
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00410
# Variancia do portfolio: 0.00005
#
# Solucionando para retorno minimo de 0.0042
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00420
# Variancia do portfolio: 0.00006
#
# Solucionando para retorno minimo de 0.0043
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00430
# Variancia do portfolio: 0.00006
#
# Solucionando para retorno minimo de 0.0044
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00440
# Variancia do portfolio: 0.00006
#
# Solucionando para retorno minimo de 0.0045
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00450
# Variancia do portfolio: 0.00006
#
# Solucionando para retorno minimo de 0.0046
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00460
# Variancia do portfolio: 0.00007
#
# Solucionando para retorno minimo de 0.0047
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00470
# Variancia do portfolio: 0.00007
#
# Solucionando para retorno minimo de 0.0048
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00480
# Variancia do portfolio: 0.00007
#
# Solucionando para retorno minimo de 0.0049
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00490
# Variancia do portfolio: 0.00007
#
# Solucionando para retorno minimo de 0.0050
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00500
# Variancia do portfolio: 0.00008
#
# Solucionando para retorno minimo de 0.0051
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00510
# Variancia do portfolio: 0.00008
#
# Solucionando para retorno minimo de 0.0052
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00520
# Variancia do portfolio: 0.00008
#
# Solucionando para retorno minimo de 0.0053
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00530
# Variancia do portfolio: 0.00008
#
# Solucionando para retorno minimo de 0.0054
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00540
# Variancia do portfolio: 0.00009
#
# Solucionando para retorno minimo de 0.0055
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00550
# Variancia do portfolio: 0.00009
#
# Solucionando para retorno minimo de 0.0056
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00560
# Variancia do portfolio: 0.00009
#
# Solucionando para retorno minimo de 0.0057
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00570
# Variancia do portfolio: 0.00010
#
# Solucionando para retorno minimo de 0.0058
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00580
# Variancia do portfolio: 0.00010
#
# Solucionando para retorno minimo de 0.0059
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00590
# Variancia do portfolio: 0.00010
#
# Solucionando para retorno minimo de 0.0060
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00600
# Variancia do portfolio: 0.00011
#
# Solucionando para retorno minimo de 0.0061
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00610
# Variancia do portfolio: 0.00011
#
# Solucionando para retorno minimo de 0.0062
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00620
# Variancia do portfolio: 0.00011
#
# Solucionando para retorno minimo de 0.0063
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00630
# Variancia do portfolio: 0.00012
#
# Solucionando para retorno minimo de 0.0064
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00640
# Variancia do portfolio: 0.00012
#
# Solucionando para retorno minimo de 0.0065
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00650
# Variancia do portfolio: 0.00012
#
# Solucionando para retorno minimo de 0.0066
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00660
# Variancia do portfolio: 0.00013
#
# Solucionando para retorno minimo de 0.0067
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00670
# Variancia do portfolio: 0.00013
#
# Solucionando para retorno minimo de 0.0068
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00680
# Variancia do portfolio: 0.00013
#
# Solucionando para retorno minimo de 0.0069
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00690
# Variancia do portfolio: 0.00014
#
# Solucionando para retorno minimo de 0.0070
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00700
# Variancia do portfolio: 0.00014
#
# Solucionando para retorno minimo de 0.0071
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00710
# Variancia do portfolio: 0.00015
#
# Solucionando para retorno minimo de 0.0072
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00720
# Variancia do portfolio: 0.00015
#
# Solucionando para retorno minimo de 0.0073
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00730
# Variancia do portfolio: 0.00015
#
# Solucionando para retorno minimo de 0.0074
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00740
# Variancia do portfolio: 0.00016
#
# Solucionando para retorno minimo de 0.0075
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00750
# Variancia do portfolio: 0.00016
#
# Solucionando para retorno minimo de 0.0076
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00760
# Variancia do portfolio: 0.00017
#
# Solucionando para retorno minimo de 0.0077
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00770
# Variancia do portfolio: 0.00017
#
# Solucionando para retorno minimo de 0.0078
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00780
# Variancia do portfolio: 0.00018
#
# Solucionando para retorno minimo de 0.0079
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00790
# Variancia do portfolio: 0.00018
#
# Solucionando para retorno minimo de 0.0080
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00800
# Variancia do portfolio: 0.00018

# %% [markdown]
# #### Exemplo de alocacao: retorno minimo = 0.008

# %%
trace1 = go.Bar(
    y=returnsIS.columns,
    x=w_opt,
    name='Alocacao',
    orientation = 'h',
    marker = dict(
        color = 'rgba(246, 78, 139, 0.6)',
        line = dict(
            color = 'rgba(246, 78, 139, 1.0)',
            width = 3)
    )
)

data = [trace1]
layout = go.Layout(
    barmode='stack',
    title='Alocacao para retorno = 0.008'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar')
# Out:
# <div id="721bf903-a4a4-41e2-b7fe-d9f1bbd2cb25" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("721bf903-a4a4-41e2-b7fe-d9f1bbd2cb25", [{"type": "bar", "y": ["ABEV3", "BVMF3", "BBDC3", "BBAS3", "SANB11", "BBSE3", "BRML3", "BBDC4", "BRAP4", "BRKM5", "BRFS3", "CCRO3", "ELET6", "CIEL3", "PCAR4", "SBSP3", "CMIG4", "CPLE6", "CSNA3", "CSAN3", "CPFE3", "CYRE3", "ECOR3", "ENBR3", "EMBR3", "EGIE3", "EQTL3", "ESTC3", "FIBR3", "FLRY3", "GGBR4", "HYPE3", "IGTA3", "ITUB4", "ITSA4", "JBSS3", "KLBN11", "KROT3", "RENT3", "LAME4", "LREN3", "MGLU3", "MRFG3", "GOAU4", "MRVE3", "MULT3", "NATU3", "PETR3", "PETR4", "QUAL3", "RADL3", "RAIL3", "SMLS3", "VIVT4", "TIMP3", "TAEE11", "UGPA3", "USIM5", "VALE3", "VVAR11"], "x": [0.1660620536951636, 0.06614263586481842, 0.12218862561254314, -0.1188605545487005, 0.11696229598096122, -0.10061633172424105, -0.23493275261593358, 0.05891472904080818, 0.45663854189723685, 0.12696239469527487, -0.30972705099610803, -0.20369297256630237, 0.051529549632377325, -0.14174702513517087, -0.1407801259309987, 0.02772783538221213, -0.13374365721002096, -0.11946580413973801, -0.11
761256723, 0.012916678861417969, 0.013082879185481913, 0.01324932883520063, 0.013416018530588379, 0.013582939434133965], "y": [0.0, 0.0001, 0.0002, 0.00030000000000000003, 0.0004, 0.0005, 0.0006000000000000001, 0.0007, 0.0008, 0.0009000000000000001, 0.001, 0.0011, 0.0012000000000000001, 0.0013000000000000002, 0.0014, 0.0015, 0.0016, 0.0017000000000000001, 0.0018000000000000002, 0.0019, 0.002, 0.0021000000000000003, 0.0022, 0.0023, 0.0024000000000000002, 0.0025, 0.0026000000000000003, 0.0027, 0.0028, 0.0029000000000000002, 0.003, 0.0031000000000000003, 0.0032, 0.0033, 0.0034000000000000002, 0.0035, 0.0036000000000000003, 0.0037, 0.0038, 0.0039000000000000003, 0.004, 0.0041, 0.004200000000000001, 0.0043, 0.0044, 0.0045000000000000005, 0.0046, 0.0047, 0.0048000000000000004, 0.0049, 0.005, 0.0051, 0.005200000000000001, 0.0053, 0.0054, 0.0055000000000000005, 0.0056, 0.0057, 0.0058000000000000005, 0.0059, 0.006, 0.0061, 0.006200000000000001, 0.0063, 0.0064, 0.006500000000000001, 0.0066, 0.0067, 0.0068000000000000005, 0.006900000000000001, 0.007, 0.0071, 0.007200000000000001, 0.0073, 0.0074, 0.007500000000000001, 0.0076, 0.0077, 0.0078000000000000005, 0.0079, 0.008], "name": "Fronteira de Portfolios"}], {"title": "Fronteira de Portfolios", "yaxis": {"title": "Retorno"}, "xaxis": {"title": "Risco"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### b. Resolva o modelo de Markowitz sem shorting e com retorno mínimo 0. Simule um portfolio iniciando em RS10000 com as proporções de Markowitz desde o primeiro até o último dia out-of-sample. Você pode utilizar a matriz `pricesOS` para fazer esta simulação.

# %% [markdown]
# ### [Resp]
#
# Para remover a possibilidade de *shorting*, o modelo do item (a) é modificado para requerer $w_i \geq 0$.

# %%
import quadprog

# Matriz de retornos para extrair parametros
RetMat = returnsIS.values.T

# Obtendo parametros fixos do modelo
Sigma = np.cov(RetMat)       # matriz de covariancia
mu = np.mean(RetMat, axis=1) # retornos medios por ativo

# Define retorno minimo
mu_min = 0

# Matrizes de otimizacao
G = Sigma                                           # matriz de custo quadratico
a = np.zeros(N)                                     # vetor de custo (nao existe)
C = np.vstack([np.ones(N), mu, np.identity(N)]).T   # matriz de m restricoes
b = np.r_[np.array([1, mu_min]), np.zeros(N)]       # termos a direita
meq = 1                                             # primeira restricao e' de igualdade

# Verificacao de dimensoes
n = N
m = N+2
assert G.shape==(n,n) and a.shape==(n,) and C.shape==(n,m) and b.shape==(m,)

# Soluciona problema quadratico
quad_sol = quadprog.solve_qp(G, a, C, b, meq)
(w_opt,f_opt) = quad_sol[0:2]

# Validacao e impressao de dados:
print('Porcentagem do orcamento investido: %.2f %%' % (np.matmul(np.ones(N),w_opt)*100))
print('Retorno do portfolio: %.5f ' % np.matmul(mu,w_opt))
print('Variancia do portfolio: %.5f \n' % f_opt)

w_mark = w_opt
# Out:
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00101
# Variancia do portfolio: 0.00003

# %% [markdown]
# #### Alocacao do valor

# %%
trace1 = go.Bar(
    y=returnsIS.columns[w_mark>1e-4],
    x=w_mark[w_mark>1e-4],
    name='Alocacao',
    orientation = 'h',
    marker = dict(
        color = 'rgba(246, 78, 139, 0.6)',
        line = dict(
            color = 'rgba(246, 78, 139, 1.0)',
            width = 3)
    )
)

data = [trace1]
layout = go.Layout(
    barmode='stack',
    title='Alocacao sem shorting para retorno minimo = 0'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar')
# Out:
# <div id="9e7f25e9-042e-435d-964b-59e6579c9263" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e7f25e9-042e-435d-964b-59e6579c9263", [{"type": "bar", "y": ["ABEV3", "CPFE3", "ENBR3", "EMBR3", "EGIE3", "EQTL3", "FIBR3", "FLRY3", "HYPE3", "RADL3", "TAEE11"], "x": [0.22379051099708308, 0.10700962372108849, 0.033672358101294333, 0.035041006095481, 0.11179370276758105, 0.09845512117722606, 0.10798014344195779, 0.08984171188934419, 0.07657293845999512, 0.05207003537724278, 0.06377284797170549], "name": "Alocacao", "orientation": "h", "marker": {"color": "rgba(246, 78, 139, 0.6)", "line": {"color": "rgba(246, 78, 139, 1.0)", "width": 3}}}], {"barmode": "stack", "title": "Alocacao sem shorting para retorno minimo = 0"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Simulação do Portfolio

# %%
port_return = lambda w: np.matmul(w,(pricesOS.iloc[-1].values / pricesOS.iloc[0].values))

print('Retorno do portfolio com as proporcoes do Markowitz: %.2f %%' % ((port_return(w_mark)-1)*100))
# Out:
# Retorno do portfolio com as proporcoes do Markowitz: 2.19 %

# %% [markdown]
# ### c. Resolva o modelo que otimiza o CVaR (Slide 60 em Downside Risk) com retorno mínimo zero, sem shorting e $\alpha = 10\%$. Faça a mesma simulação da letra b., mas desta vez com as proporções obtidas no modelo do CVaR.

# %% [markdown]
# ### [Resp]
#
# A formulação linear para o problema é a seguinte:
#
# \begin{align}
#     &\underset{w, \theta}{\text{minimize}} & &\theta + \frac{1}{S\alpha}\sum_{t=1}^{S}d_t &&\equiv
#     &&\theta + \frac{1}{S\alpha}\sum\mathbf{d} &&\equiv
#     &&\left[1 \ |\ \mathbf{0}^{N^T}  \ |\ \mathbf{\frac{1}{S\alpha}}^{S^T} \right] \mathbf{x}\\
#     %
#     &\text{sujeito a} &&d_t \geq -\theta - \sum_{i=1}^{N}r_{it}w_i, \quad t \in S &&\equiv
#     &&-\theta - \mathbf{r_t}^T\mathbf{w}  -d_t\leq 0, \quad t \in S &&\equiv
#     &&-\left[\mathbf{1}^{S} \ |\ \mathbf{R}  \ |\ \mathbf{I}_S\right] \mathbf{x} &&\leq \mathbf{0}^{S^T}\\
#     %
#     %& &&p_{t} = \sum_{i=1}^{N}r_{it}w_i, \quad t \in S &&\equiv
#     %&&- \mathbf{R}\mathbf{w} + \mathbf{p} = 0 &&\equiv
#     %&&\left[\mathbf{0}^{S} \ |\ -\mathbf{R}  \ |\ \mathbf{0}_{SxS}  \ |\ \mathbf{I}_S \right] \mathbf{x} &&= \mathbf{0}^{S^T}\\
#     %
#     & &&\sum_{i=1}^{N}w_i\mu_i \geq \overline{\mu} &&\equiv &&\mathbf{\mu^T}\mathbf{w} \geq \overline{\mu} &&\equiv
#     &&\left[0 \ |\ -\mathbf{\mu^T}  \ |\ \mathbf{0}^{S^T} \right] \mathbf{x} &&\leq - \overline{\mu}\\
#     & &&\sum_{i=1}^{N}w_i = 1 &&\equiv &&\mathbf{1^T}\mathbf{w} = 1  &&\equiv
#     &&\left[0 \ |\ \mathbf{1}^{N^T}  \ |\ \mathbf{0}^{S^T} \right] \mathbf{x} &&= 1\\
#     %
#     & &&w_i \geq 0  \\
#     & &&d_t \geq 0  \\
#     & &&\theta \geq 0  \\
#     %
#     &\text{tal que} && \mathbf{x} = \left[\theta \ |\ \mathbf{w}  \ |\ \mathbf{d} \right]\\
#     & &&\mathbf{x} \in \mathbb{R}^{(1+N+S)}\\
#     & &&\mathbf{R} \in \mathbb{R}^{SxN}
# \end{align}
#
# em que $\theta$ é o VaR no nível $\alpha$.
#
# - As variáveis de decisão são $w$ e $\theta$.
# - Os parâmetros fixos do modelo - $S$ cenários, retornos $r_{it}$ e retornos médios $\mu_i$ - são obtidos do conjunto `returnsIS`.
# - Já os parâmetros variáveis do modelo - retorno mínimo $\overline{\mu}$ e nível $\alpha$ - são definido como $0$ e $0.10$, conforme o enunciado.
#
# A formulação faz com que, quanto menor o nível $\alpha$, maior o peso dado à soma das diferenças $d_t$. A forma do modelo contrabalancear este efeito é aumentando o valor de $\theta$, o que, por sua vez, representa um maior Value at Risk.

# %%
import scipy.optimize as sco
# Minimize:     c^T * x

# Subject to:   A_ub * x <= b_ub
#               A_eq * x == b_eq

# Matriz de retornos para extrair parametros
R = returnsIS.values

# Obtendo parametros fixos do modelo
mu = np.mean(R, axis=0) # retornos medios por ativo

# Define retorno minimo e nivel do VaR
mu_min = 0
alpha = 0.1


# Vetor de decisao - x = [theta, w, d, p]
n = 1+N+S # numero de variaveis

# Funcao objetivo
c = np.r_[1, np.zeros(N), np.full(S,fill_value=(1/(S*alpha)))]

# Restricoes de desigualdade
A_ub_1 = -np.hstack([np.ones((S,1)), R, np.identity(S)])
A_ub_2 = np.hstack([0, -mu, np.zeros((S,))])
A_ub = np.vstack([A_ub_1, A_ub_2])
b_ub = np.r_[np.zeros(S,), -mu_min]

# Restricao de igualdade
A_eq = np.hstack([np.zeros((1,1)), np.ones((1,N)), np.zeros((1,S))])
b_eq = np.array([1])

# Bounds
bounds = [(0,None)] + [(0,None)]*N + [(0,None)]*S

# Verifica dimensoes
assert c.shape==(n,) and A_ub_1.shape==(S,n) and A_ub_2.shape==(n,) and A_ub.shape==(S+1,n) and \
       b_ub.shape==(S+1,) and A_eq.shape==(1,n) and b_eq.shape==(1,) and R.shape==(S,N) and mu.shape==(N,)
        
# Soluciona problema linear
sol = sco.linprog(c, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=bounds,options={"disp": False})

# Extrai variaveis otimas
x_opt = sol.x
theta_opt = x_opt[0]  # VaR
w_opt = x_opt[1:1+N] # Alocacao (pesos w)

# Validacao e impressao de dados:
print('Porcentagem do orcamento investido: %.2f %%' % (np.matmul(np.ones(N),w_opt)*100))
print('Retorno do portfolio: %.5f ' % np.matmul(mu,w_opt))
print('VaR 10%%: %.5f \n' % theta_opt)

w_cvar = w_opt
# Out:
# Porcentagem do orcamento investido: 100.00 %
# Retorno do portfolio: 0.00132
# VaR 10%: 0.00798

# %% [markdown]
# #### Alocacao do valor

# %%
trace1 = go.Bar(
    y=returnsIS.columns[w_cvar>1e-4],
    x=w_cvar[w_cvar>1e-4],
    name='Alocacao',
    orientation = 'h',
    marker = dict(
        color = 'rgba(246, 78, 139, 0.6)',
        line = dict(
            color = 'rgba(246, 78, 139, 1.0)',
            width = 3)
    )
)

data = [trace1]
layout = go.Layout(
    barmode='stack',
    title='Alocacao sem shorting para retorno minimo = 0'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar')
# Out:
# <div id="7d293d11-d097-4c00-bf52-0b6bf62bf900" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7d293d11-d097-4c00-bf52-0b6bf62bf900", [{"type": "bar", "y": ["ABEV3", "BRKM5", "CPFE3", "EGIE3", "EQTL3", "FIBR3", "FLRY3", "HYPE3", "MRFG3", "QUAL3", "RADL3", "TAEE11"], "x": [0.08858150188597064, 0.003194143475032942, 0.15056096945430741, 0.09899584565951869, 0.07251155035344478, 0.12562943730847917, 0.17381182555365682, 0.03453145917636836, 0.004717756383873044, 0.021062595580641698, 0.08010720593416576, 0.14629570923454044], "name": "Alocacao", "orientation": "h", "marker": {"color": "rgba(246, 78, 139, 0.6)", "line": {"color": "rgba(246, 78, 139, 1.0)", "width": 3}}}], {"barmode": "stack", "title": "Alocacao sem shorting para retorno minimo = 0"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Simulação do Portfolio

# %%
print('Retorno do portfolio com as proporcoes do CVaR: %.2f %%' % ((port_return(w_cvar)-1)*100))
# Out:
# Retorno do portfolio com as proporcoes do CVaR: 1.75 %

# %% [markdown]
# ### d. Plote um gráfico contendo as performances normalizadas dos portfolios baseados em Markowitz e CVaR, além do índice iBov. O vetor `indexPricesOS` contém os dados do out-of-sample do índice.

# %%
n_mark = 10000*w_mark/(pricesOS.iloc[0].values) # quantidade de papeis de cada ativo - Markowitz
n_cvar = 10000*w_cvar/(pricesOS.iloc[0].values) # quantidade de papeis de cada ativo - CVaR
ibov_mult = 10000/indexPriceOS.iloc[0]

port_dict = {'portfolio_Mark':pricesOS.apply(lambda x: np.matmul(x,n_mark),axis=1),
             'portfolio_CVaR':pricesOS.apply(lambda x: np.matmul(x,n_cvar),axis=1),
             'valor_iBov':indexPriceOS.values*ibov_mult}
port_df = pd.DataFrame(data=port_dict, index=pricesOS.index)

# %%
plotscatter(port_df,yaxis='Valor do Portfolio',title='Desempenhos dos Portfolios Markowitz/CVaR e Indice iBov')
# Out:
# <div id="fc131be0-83bf-418e-8f54-cca85898a29a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fc131be0-83bf-418e-8f54-cca85898a29a", [{"type": "scatter", "x": ["2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01"], "y": [9999.999999999998, 9949.577184850019, 9770.821399096261, 9794.658483840241, 9882.0211199966, 9794.432838941064, 9736.483970571278, 9947.584241157427, 9966.56575897934, 10067.723786271603, 10099.88722864583, 10259.632748686843, 10256.419360048867, 10291.567675842736, 10315.340179439765, 10308.47505527647, 10259.719698899615, 10155.30608568275, 10175.287131084591], "name": "portfolio_CVaR"}, {"type": "scatter", "x": ["2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01"], "y": [9999.999999999996, 9957.333355306637, 9787.817198829103, 9825.552955341918, 9887.481633419315, 9807.866513725785, 9750.70202507816, 9961.932057559174, 9982.613136741105, 10094.887026578073, 10139.723395805546, 10312.702176479408, 10274.196756807083, 10309.36862294948, 10304.235892149347, 10288.893601077652, 10286.447489524211, 10174.029711518782, 10219.339968200797], "name": "portfolio_Mark"}, {"type": "scatter", "x": ["2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01"], "y": [10000.0, 9829.943748915144, 9574.929551633517, 9812.714719556316, 9680.858255968402, 9536.499341951669, 9462.363050855229, 9771.63640923167, 9859.095079445358, 9886.466193907403, 9917.828173825817, 10036.10961265212, 10065.100700343084, 10139.3305639004, 10210.304105819225, 10252.34153386785, 10168.45382269235, 9983.432995801872, 9986.262393087614], "name": "valor_iBov"}], {"title": "Desempenhos dos Portfolios Markowitz/CVaR e Indice iBov", "legend": {"orientation": "h"}, "yaxis": {"title": "Valor do Portfolio"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### e. Calcule, a partir dos valores out-of-sample obtidos, algumas medidas de performance dos portfolios e do índice:
# 1. **Variância**
# - **CVaR 10%**
# - **Sharpe ratio**
# - **Sortino ratio**
# - **Drawdown máximo**
# - **Betas dos portfolios em relação ao índice.**
#
# Observe que neste exercício não vamos rebalancear o portfolio periodicamente. Isto é, o portfolio é
# comprado" no início e não mais alterado até o final. Calculamos o seu valor dia após dia até o final da
# série.

# %% [markdown]
# ### [Resp]
#
# - **Variância**: $$\sum_{i=1}^{N}\sum_{j=1}^{N}w_iw_j\sigma_{ij}$$.
# - **CVaR 10%**: $$CVaR_{\alpha} = \frac{1}{\alpha}\sum_{t=1}^{T}u_tR_t$$ em que os T cenários são obtidos de `pricesOS`. <br> <br>
# - **Sharpe ratio**: $$Sh_P = \frac{\mu_P - R_f}{\sigma_P}$$ em que $\mu$ e $\sigma$ são obtidos das séries dos portfólios para o período *out of sample*. <br> <br>
# - **Sortino ratio**: $$So_P = \frac{\mu_P - R_f}{\widehat{\sigma}_P}$$ em que $\mu$ e $\widehat{\sigma}$ são obtidos das séries dos portfólios para o período *out of sample*. <br> <br>
# - **Drawdown máximo**: MDD = (Trough Value – Peak Value) ÷ Peak Value <br> <br>
# - **Betas dos portfólios em relação ao índice**: $$\beta_P = \frac{\sigma_{ind,P}}{\sigma_{ind}^2}$$ em que o índice é o `IBOV`.

# %%
# Variancia
print('Variancias dos portfolios/iBov:')
print(port_df.var(),'\n\n')

# CVaR 10%
alpha = 0.1
OS = pricesOS.shape[0]
u_vec = np.full(int(np.floor(alpha*OS)),fill_value=1/OS) # pesos de cada um dos piores alpha cenarios
u_vec = np.r_[u_vec, alpha-np.sum(u_vec)]
returns_port = (port_df.diff() / port_df.shift(axis=0, periods=1)).iloc[1:]
cvar_ret = returns_port.apply(func=np.sort, axis=0).iloc[:u_vec.shape[0]]
cvar_df=pd.DataFrame(data=[np.matmul(u_vec,cvar_ret.values)],index=['CVaR_10%'],columns=returns_port.columns)
print('CVaR 10%% dos portfolios/iBov:')
print(cvar_df,'\n\n')

# Sharpe
Rf = 0
Sharpe = (returns_port.mean() - Rf)/(returns_port.std())
print('Sharpe Ratio dos portfolios/iBov:')
print(Sharpe,'\n\n')

# Sortino
Rf = 0
Sortino = (returns_port.mean() - Rf)/(returns_port.applymap(lambda x: min(x,0)).std())
print('Sortino Ratio dos portfolios/iBov:')
print(Sortino,'\n\n')

# Drawdown Maximo
def MDD(x):
    mdd=0
    for i in range(len(x)-1):
        for j in range(i+1,len(x)):
            if x[i]-x[j] > mdd: mdd=x[i]-x[j]
    return mdd
print('Maximum Drawdown dos portfolios/iBov:')
print(port_df.apply(func=MDD, axis=0),'\n\n')

# Betas em relacao ao indice
cov1 = np.cov(port_df['portfolio_Mark'].values, port_df['valor_iBov'].values)[0,1]
cov2 = np.cov(port_df['portfolio_CVaR'].values, port_df['valor_iBov'].values)[0,1]
print('Sortino Ratio dos portfolios/iBov (< 1 reduz volatilidade):')
print('Markowitz: %f' % (cov1 / np.var(port_df['valor_iBov'].values)))
print('CVaR: %f' % (cov2 / np.var(port_df['valor_iBov'].values)),'\n\n')
# Out:
# Variancias dos portfolios/iBov:
# portfolio_CVaR    40019.174530
# portfolio_Mark    40352.071883
# valor_iBov        51567.289553
# dtype: float64
#
#
# CVaR 10%% dos portfolios/iBov:
#           portfolio_CVaR  portfolio_Mark  valor_iBov
# CVaR_10%       -0.001428       -0.001414   -0.002227
#
#
# Sharpe Ratio dos portfolios/iBov:
# portfolio_CVaR    0.106806
# portfolio_Mark    0.132342
# valor_iBov        0.002054
# dtype: float64
#
#
# Sortino Ratio dos portfolios/iBov:
# portfolio_CVaR    0.200802
# portfolio_Mark    0.259830
# valor_iBov        0.003684
# dtype: float64
#
#
# Maximum Drawdown dos portfolios/iBov:
# portfolio_CVaR    263.516029
# portfolio_Mark    249.297975
# valor_iBov        537.636949
# dtype: float64
#
#
# Sortino Ratio dos portfolios/iBov (< 1 reduz volatilidade):
# Markowitz: 0.865072
# CVaR: 0.874062

# %% [markdown]
# # <span style='color:darkmagenta'>Questao 2.</span>
#
# Considere um modelo de seleção de portfolios com shorting. Queremos limitar a quantidade
# de shorting em no máximo 20% do valor total do portfolio. A solução dada pelo modelo (seja Markowitz
# ou qualquer outro) deve garantir este limite. Como podemos fazer isso?

# %% [markdown]
# ### [Resp]
#
# #### Opção 1:
#
# Incluir variáveis de folga $l_i$ restritas da seguinte forma:
# \begin{align}
# &w_i + l_i &&\geq 0, \quad &&\forall i\\
# &\sum_{i=1}^{N} l_i &&\leq 0.2 \\
# &l_i &&\geq 0, \quad &&\forall i \\
# \end{align}
#
# #### Opção 2:
#
# Desacoplar o shorting ($w_i \leq 0$) do long, fazendo a seguinte substituição:<br><br>
# $$ w_i = w^{+}_i - w^{-}_i $$ <br>
# tal que $w^{+}_i, w^{-}_i \geq 0$.
#
# Com isto, basta incluir a restrição
# $$ \sum_{i=1}^{N} w^{-}_i \leq 0.2$$

# %% [markdown]
# # <span style='color:darkmagenta'>Questao 3.</span>
#
# Por que, na prática, fundos que escolhem portfolios baseados em Markowitz também utilizam
# o modelo de Black-Litterman?

# %% [markdown]
# ### [Resp]
#
# Pois ele ajuda a superar algumas dificuldades clássicas do modelo média-variância de Markowitz, tais como:
# - portfolios altamente concentrados e não intuitivos;
# - alta sensibilidade aos parâmetros de entrada;
# - excesso de estimativas, com alta possibilidade de erros.

# %% [markdown]
# # <span style='color:darkmagenta'>Desafio.</span>
#
# Considere o modelo de otimização abaixo. O modelo assume, para cada ativo $i$, um portfolio atual composto por $X_i$ ações e proporções desejadas $w_i^*$, encontradas previamente, indicando como devemos dividir o novo portfolio. Considere também $P_i$ como o preço atual de $i$ e $f$ como o custo aplicado a cada transação e expresso como uma porcentagem do valor negociado.
# O modelo utiliza variáveis $x_i$ indicando quantas ações de $i$ teremos após as negociações e $G_i$ indicando o valor financeiro gasto para alterarmos a composição de $i$ de $X_i$ para $x_i$ ações. Este modelo garante que gastaremos o mínimo possível nestes custos.
#
#
# \begin{align}
#     &\underset{\mathbf{x}}{\text{minimize}} & &\sum_{i=1}^{N}G_i\\
#     %
#     &\text{sujeito a} &&P_ix_i = w_i^* \left( \sum_{j=1}^{N}X_jP_j - \sum_{j=1}^{N}G_j \right) &&j = 1,..., N \\
#     & &&G_i \geq (x_i - X_i)P_if &&j = 1,..., N \\
#     & &&G_i \geq (X_i - x_i)P_if &&j = 1,..., N \\
# \end{align}
#
#
# O modelo inclui apenas custos variáveis (uma porcentagem do valor a ser negociado). Considere que,
# além do custo variável, temos um custo fixo h, expresso em moeda, a ser aplicado a cada negociação.
# Este valor é independente do tamanho da negociação. Altere o modelo acima para que inclua o custo
# fixo.

# %% [markdown]
# ### [Resp]
#
# Se incluirmos uma variável binária que indique a existência de uma transação, podemos incluir o custo fixo:
#
# \begin{align}
#     &\underset{\mathbf{x}}{\text{minimize}} & &\sum_{i=1}^{N}G_i + h\sum_{i=1}^{N}H_i\\
#     %
#     &\text{sujeito a} &&P_ix_i = w_i^* \left( \sum_{j=1}^{N}X_jP_j - \sum_{j=1}^{N}G_j - h\sum_{j=1}^{N}H_j \right) &&j = 1,..., N \\
#     & &&G_i \geq (x_i - X_i)P_if &&i = 1,..., N \\
#     & &&G_i \geq (X_i - x_i)P_if &&i = 1,..., N \\
#     & &&H_i \geq (X_i - x_i) / M &&i = 1,..., N \\
#     & &&H_i \geq (X_i - x_i) / M &&i = 1,..., N \\
#     & &&H_i \in \{0,1\}  &&i = 1,..., N \\
# \end{align}
#
# em que $M$ é um "número grande", que faça com que $|x_i - X_i|$ nunca seja maior que $1$. Um valor válido é então <br><br> $$M = \frac{\sum_{i=1}^{N}X_iP_i} / min(X_i)$$.
